# %%
# imports

from easyocr import Reader
import argparse
import cv2
import matplotlib.pyplot as plt

# %%
def cleanup_text(text):
    return "".join([c if ord(c) < 128 else "" for c in text]).strip()

# %% [markdown]
# ## Testing with the license plate number

# %%
# Direct assignments for Jupyter
image_path = "../images/AM3808CO.jpg"  # Replace with your image path
langs = ["en"]  # List of languages for OCR
use_gpu = False  # Set to True if you want to use GPU and it's available

# %%
# Load the input image from disk
image = cv2.imread(image_path)

# %%
# OCR the input image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(image)
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...

# %%
# Loop over the results
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
# Out:
# [INFO] 0.1597: CEZEJOD
# [INFO] 0.1150: DD
# [INFO] 0.7071: AM3808 CO
# [INFO] 0.0000: Tanntntamene nmancentn Hipberi

# %%
# Convert BGR (OpenCV) to RGB (Matplotlib)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# Show the output image
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Test 11

# %%
# Image path and settings
image_path = "../images/alfa-romeo-milano-2.jpg"
langs = ["en"]  # Adjust if necessary
use_gpu = False  # Use GPU if available and properly configured

# Load and preprocess the image
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
_, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  # Apply thresholding

# OCR the preprocessed image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(binary_image)

# Loop over the results and draw bounding boxes
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Convert BGR (OpenCV) to RGB (Matplotlib) and display the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.2860: 72)
# [INFO] 0.3786: HHAR 024ML
# [INFO] 0.0454: J
# [INFO] 0.7063: 1
# [INFO] 0.0000:
# [INFO] 0.0717: 2
# [INFO] 0.4939: J
# [INFO] 0.4006: 1
# [INFO] 0.1753: L
# [INFO] 0.1059: 1
# [INFO] 0.1759: 0
# [INFO] 0.0763: 3tn
# [INFO] 0.0448: "nsth
# [INFO] 0.7132: 1
# [INFO] 0.3719: 1
# [INFO] 0.0240: ~in
# [INFO] 0.0528: 41442n4
# [INFO] 0.4816: 1

# %% [markdown]
# ## Test 3

# %%
# Image path and settings
image_path = "../images/SN66XMZ.jpg"
langs = ["en"]  # Adjust if necessary
use_gpu = False  # Use GPU if available and properly configured

# Load and preprocess the image
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
_, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  # Apply thresholding

# OCR the preprocessed image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(binary_image)

# Loop over the results and draw bounding boxes
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Convert BGR (OpenCV) to RGB (Matplotlib) and display the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.5165: 2r0
# [INFO] 0.8263: SN66 XMZ

# %% [markdown]
# ## Test 4

# %%
# Image path and settings
image_path = "../images/AM3808CO.jpg"
langs = ["en"]  # Adjust if necessary
use_gpu = False  # Use GPU if available and properly configured

# Load and preprocess the image
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
_, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  # Apply thresholding

# OCR the preprocessed image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(binary_image)

# Loop over the results and draw bounding boxes
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Convert BGR (OpenCV) to RGB (Matplotlib) and display the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.5768: 41
# [INFO] 0.7364: AM 3808 CQ

# %% [markdown]
# ## Test 5

# %%
# Image path and settings
image_path = "/Users/olgatsyban/Documents/car5.png"
langs = ["en"]  # Adjust if necessary
use_gpu = False  # Use GPU if available and properly configured

# Load and preprocess the image
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
_, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  # Apply thresholding

# OCR the preprocessed image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(binary_image)

# Loop over the results and draw bounding boxes
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Convert BGR (OpenCV) to RGB (Matplotlib) and display the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# [ WARN:0@543.204] global loadsave.cpp:241 findDecoder imread_('/Users/olgatsyban/Documents/car5.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[24], line 8
#       6 # Load and preprocess the image
#       7 image = cv2.imread(image_path)
# ----> 8 gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
#       9 _, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  # Apply thresholding
#      11 # OCR the preprocessed image using EasyOCR
#
# error: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# ## Test 6

# %%
# Image path and settings
image_path = "/Users/olgatsyban/Documents/car6.png"
langs = ["en"]  # Adjust if necessary
use_gpu = False  # Use GPU if available and properly configured

# Load and preprocess the image
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
_, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  # Apply thresholding

# OCR the preprocessed image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(binary_image)

# Loop over the results and draw bounding boxes
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Convert BGR (OpenCV) to RGB (Matplotlib) and display the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.6936: "KE 3198 AE

# %% [markdown]
# ## Test 8

# %%
# Image path and settings
image_path = "/Users/olgatsyban/Documents/car8.png"
langs = ["en"]  # Adjust if necessary
use_gpu = False  # Use GPU if available and properly configured

# Load and preprocess the image
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
_, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  # Apply thresholding

# OCR the preprocessed image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(binary_image)

# Loop over the results and draw bounding boxes
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Convert BGR (OpenCV) to RGB (Matplotlib) and display the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.9905: 1696EM
# [INFO] 0.9830: AM

# %% [markdown]
# ## Test 9

# %%
# Image path and settings
image_path = "/Users/olgatsyban/Documents/car9.png"
langs = ["en"]  # Adjust if necessary
use_gpu = False  # Use GPU if available and properly configured

# Load and preprocess the image
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
_, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  # Apply thresholding

# OCR the preprocessed image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(binary_image)

# Loop over the results and draw bounding boxes
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Convert BGR (OpenCV) to RGB (Matplotlib) and display the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.9996: A
# [INFO] 0.8967: 0001 S

# %% [markdown]
# ## Test 10

# %%
# Image path and settings
image_path = "/Users/olgatsyban/Documents/car10.png"
langs = ["en"]  # Adjust if necessary
use_gpu = False  # Use GPU if available and properly configured

# Load and preprocess the image
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
_, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  # Apply thresholding

# OCR the preprocessed image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(binary_image)

# Loop over the results and draw bounding boxes
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Convert BGR (OpenCV) to RGB (Matplotlib) and display the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.9988: CA
# [INFO] 0.9797: 2218
# [INFO] 0.8635: T
