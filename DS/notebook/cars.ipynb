# %%
# imports

from easyocr import Reader
import argparse
import cv2
import matplotlib.pyplot as plt

# %%
def cleanup_text(text):
    return "".join([c if ord(c) < 128 else "" for c in text]).strip()

# %% [markdown]
# ## Testing with the license plate number

# %%
# Direct assignments for Jupyter
image_path = "/Users/olgatsyban/Documents/car2.png"  # Replace with your image path
langs = ["en"]  # List of languages for OCR
use_gpu = False  # Set to True if you want to use GPU and it's available

# %%
# Load the input image from disk
image = cv2.imread(image_path)

# %%
# OCR the input image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(image)
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...

# %%
# Loop over the results
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
# Out:
# [INFO] 0.9999: UA
# [INFO] 0.8966: AA 5153 KA

# %%
# Convert BGR (OpenCV) to RGB (Matplotlib)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# Show the output image
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Test 11

# %%
# Image path and settings
image_path = "/Users/olgatsyban/Documents/car11.png"
langs = ["en"]  # Adjust if necessary
use_gpu = False  # Use GPU if available and properly configured

# Load and preprocess the image
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
_, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  # Apply thresholding

# OCR the preprocessed image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(binary_image)

# Loop over the results and draw bounding boxes
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Convert BGR (OpenCV) to RGB (Matplotlib) and display the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.7801: "BX 5539EP

# %% [markdown]
# ## Test 3

# %%
# Image path and settings
image_path = "/Users/olgatsyban/Documents/car3.png"
langs = ["en"]  # Adjust if necessary
use_gpu = False  # Use GPU if available and properly configured

# Load and preprocess the image
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
_, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  # Apply thresholding

# OCR the preprocessed image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(binary_image)

# Loop over the results and draw bounding boxes
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Convert BGR (OpenCV) to RGB (Matplotlib) and display the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.7763: KA7777CA

# %% [markdown]
# ## Test 4

# %%
# Image path and settings
image_path = "/Users/olgatsyban/Documents/car4.png"
langs = ["en"]  # Adjust if necessary
use_gpu = False  # Use GPU if available and properly configured

# Load and preprocess the image
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
_, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  # Apply thresholding

# OCR the preprocessed image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(binary_image)

# Loop over the results and draw bounding boxes
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Convert BGR (OpenCV) to RGB (Matplotlib) and display the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.8338: KL 55R 2473

# %% [markdown]
# ## Test 5

# %%
# Image path and settings
image_path = "/Users/olgatsyban/Documents/car5.png"
langs = ["en"]  # Adjust if necessary
use_gpu = False  # Use GPU if available and properly configured

# Load and preprocess the image
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
_, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  # Apply thresholding

# OCR the preprocessed image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(binary_image)

# Loop over the results and draw bounding boxes
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Convert BGR (OpenCV) to RGB (Matplotlib) and display the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.9848: IND
# [INFO] 0.4262: CG 07 0 5599

# %% [markdown]
# ## Test 6

# %%
# Image path and settings
image_path = "/Users/olgatsyban/Documents/car6.png"
langs = ["en"]  # Adjust if necessary
use_gpu = False  # Use GPU if available and properly configured

# Load and preprocess the image
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
_, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  # Apply thresholding

# OCR the preprocessed image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(binary_image)

# Loop over the results and draw bounding boxes
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Convert BGR (OpenCV) to RGB (Matplotlib) and display the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.6936: "KE 3198 AE

# %% [markdown]
# ## Test 8

# %%
# Image path and settings
image_path = "/Users/olgatsyban/Documents/car8.png"
langs = ["en"]  # Adjust if necessary
use_gpu = False  # Use GPU if available and properly configured

# Load and preprocess the image
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
_, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  # Apply thresholding

# OCR the preprocessed image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(binary_image)

# Loop over the results and draw bounding boxes
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Convert BGR (OpenCV) to RGB (Matplotlib) and display the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.9905: 1696EM
# [INFO] 0.9830: AM

# %% [markdown]
# ## Test 9

# %%
# Image path and settings
image_path = "/Users/olgatsyban/Documents/car9.png"
langs = ["en"]  # Adjust if necessary
use_gpu = False  # Use GPU if available and properly configured

# Load and preprocess the image
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
_, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  # Apply thresholding

# OCR the preprocessed image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(binary_image)

# Loop over the results and draw bounding boxes
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Convert BGR (OpenCV) to RGB (Matplotlib) and display the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.9996: A
# [INFO] 0.8967: 0001 S

# %% [markdown]
# ## Test 10

# %%
# Image path and settings
image_path = "/Users/olgatsyban/Documents/car10.png"
langs = ["en"]  # Adjust if necessary
use_gpu = False  # Use GPU if available and properly configured

# Load and preprocess the image
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
_, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  # Apply thresholding

# OCR the preprocessed image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=use_gpu)
results = reader.readtext(binary_image)

# Loop over the results and draw bounding boxes
for (bbox, text, prob) in results:
    print("[INFO] {:.4f}: {}".format(prob, text))
    (tl, tr, br, bl) = bbox
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    text = cleanup_text(text)
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    cv2.putText(image, text, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Convert BGR (OpenCV) to RGB (Matplotlib) and display the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.9988: CA
# [INFO] 0.9797: 2218
# [INFO] 0.8635: T
